# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the x-values
x = np.array([1e-9, 1e-8, 1e-7])

# Define y-values for three different lines
#y1 = np.array([42.35892834437077, 41.36199200274051, 42.29966634031672])
#y2 = np.array([42.39271591406758, 42.31981364023877, 42.386182496092076])
#y3 = np.array([42.35892834437077, 41.36199200274051, 42.29966634031672])
#y4 = np.array([42.19813374565856, 41.50731470862877, 41.92388010081153])

y1 = np.array([0.9852929382619342, 0.9820775092127713, 0.9851882870231274])
y2 = np.array([0.9852715724535616, 0.9852562487625091, 0.9853749004007838])
y3 = np.array([0.9852929382619342, 0.9820775092127713, 0.9851882870231274])
y4 = np.array([0.9848864517443668, 0.982625008276854, 0.9840761268426594])

# Create the plot
plt.figure(figsize=(10, 6))

# Plot each line
plt.plot(x, y1, label='CG', marker='o', color='blue')
plt.plot(x, y2, label='GD', marker='s', color='green')
plt.plot(x, y3, label='jCG', marker='^', color='red')
plt.plot(x, y4, label='jN', marker='.', color='yellow')


# Set the x-axis to log scale to better visualize the small values
plt.xscale('log')

# Set y-axis limits
plt.ylim(0.98, 0.99)

# Add labels and a title
plt.xlabel('Beta')
plt.ylabel('SSIM')
plt.title('Comparison f_s')

# Add a legend
plt.legend()

# Show grid
plt.grid(True)
plt.savefig('SSIM_comparison.png')


# Display the plot
plt.show()
